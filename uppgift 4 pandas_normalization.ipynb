# %%
#import methode
import pandas as pd
import numpy as np
import math

# %%
#import csv file and display
data = pd.read_csv('Automobile.csv', index_col=0)
data.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
#calculate wheel min-max normalization and z-score
wheel = data[['wheel-base']]
wheel['min-man normalization']=(wheel['wheel-base'] -wheel['wheel-base'].mean())/(wheel['wheel-base'].max()-wheel['wheel-base'].min())
wheel['z-score']=(wheel['wheel-base']-wheel['wheel-base'].mean())/(wheel['wheel-base'].std(ddof=0))
wheel
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\1577167524.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wheel['min-man normalization']=(wheel['wheel-base'] -wheel['wheel-base'].mean())/(wheel['wheel-base'].max()-wheel['wheel-base'].min())
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\1577167524.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wheel['z-score']=(wheel['wheel-base']-wheel['wheel-base'].mean())/(wheel['wheel-base'].std(ddof=0))
# ...

# %%
#calculate length min-max normalization and z-score
length=data[['length']]
length['min-man normalization']=(length['length'] -length['length'].mean())/(length['length'].max()-length['length'].min())
length['z-score']=(length['length']-length['length'].mean())/(length['length'].std(ddof=0))
length
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\1299892241.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   length['min-man normalization']=(length['length'] -length['length'].mean())/(length['length'].max()-length['length'].min())
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\1299892241.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   length['z-score']=(length['length']-length['length'].mean())/(length['length'].std(ddof=0))
#        length  min-man normalization   z-score
# ...

# %%
#calculate power min-max normalization and z-score
power=data[['horsepower']]
power['min-man normalization']=(power['horsepower'] -power['horsepower'].mean())/(power['horsepower'].max()-power['horsepower'].min())
power['z-score']=(power['horsepower']-power['horsepower'].mean())/(power['horsepower'].std(ddof=0))
power
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\874375653.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   power['min-man normalization']=(power['horsepower'] -power['horsepower'].mean())/(power['horsepower'].max()-power['horsepower'].min())
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\874375653.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   power['z-score']=(power['horsepower']-power['horsepower'].mean())/(power['horsepower'].std(ddof=0))
# ...

# %%
#calculate average min-max normalization and z-score
average=data[['average-mileage']]
average['min-man normalization']=(average['average-mileage'] -average['average-mileage'].mean())/(average['average-mileage'].max()-average['average-mileage'].min())
average['z-score']=(average['average-mileage']-average['average-mileage'].mean())/(average['average-mileage'].std(ddof=0))
average
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\2621968835.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   average['min-man normalization']=(average['average-mileage'] -average['average-mileage'].mean())/(average['average-mileage'].max()-average['average-mileage'].min())
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\2621968835.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#calculate price min-max normalization and z-score
price=data[['price']]
price['min-man normalization']=(price['price'] -price['price'].mean())/(price['price'].max()-price['price'].min())
price['z-score']=(price['price']-price['price'].mean())/(price['price'].std(ddof=0))
price
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\2680471270.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price['min-man normalization']=(price['price'] -price['price'].mean())/(price['price'].max()-price['price'].min())
# C:\Users\admin\AppData\Local\Temp\ipykernel_4696\2680471270.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price['z-score']=(price['price']-price['price'].mean())/(price['price'].std(ddof=0))
#          price  min-man normalization   z-score
# index
# ...

# %%
#pack every dataframe
df =data[['company']]
result=pd.concat([df,wheel,length,power,average,price],axis=1)
result
# Out:
#            company  wheel-base  min-man normalization   z-score  length  \
# index
# 0      alfa-romero        88.6              -0.304061 -1.491784   168.8
# 1      alfa-romero        88.6              -0.304061 -1.491784   168.8
# 2      alfa-romero        94.5              -0.122522 -0.601119   171.2
# 3             audi        99.8               0.040555  0.198971   176.6
# 4             audi        99.4               0.028247  0.138586   176.6
# ...            ...         ...                    ...       ...     ...
# 81      volkswagen        97.3              -0.036368 -0.178430   171.7
# 82      volkswagen        97.3              -0.036368 -0.178430   171.7
# 86      volkswagen        97.3              -0.036368 -0.178430   171.7
# 87           volvo       104.3               0.179016  0.878292   188.8
# 88           volvo       104.3               0.179016  0.878292   188.8
#
#        min-man normalization   z-score  horsepower  min-man normalization  \
# index
# ...

# %%
#export dataframe as csv's file
result.to_csv('newauto.csv')

# %%
#test file
test = pd.read_csv('newauto.csv')
test
# Out:
#     index      company  wheel-base  min-man normalization   z-score  length  \
# 0       0  alfa-romero        88.6              -0.304061 -1.491784   168.8
# 1       1  alfa-romero        88.6              -0.304061 -1.491784   168.8
# 2       2  alfa-romero        94.5              -0.122522 -0.601119   171.2
# 3       3         audi        99.8               0.040555  0.198971   176.6
# 4       4         audi        99.4               0.028247  0.138586   176.6
# ..    ...          ...         ...                    ...       ...     ...
# 56     81   volkswagen        97.3              -0.036368 -0.178430   171.7
# 57     82   volkswagen        97.3              -0.036368 -0.178430   171.7
# 58     86   volkswagen        97.3              -0.036368 -0.178430   171.7
# 59     87        volvo       104.3               0.179016  0.878292   188.8
# 60     88        volvo       104.3               0.179016  0.878292   188.8
#
# ...
